# %%
import pandas as pd
import pickle

# %%
df = pd.read_pickle('preprocess_info/preprocess_info.pkl')

# %%
df['low_cardinality_features']
# Out:
# ['ProductCD',
#  'card4',
#  'card6',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'DeviceType',
#  'id_12',
#  'id_15',
#  'id_16',
#  'id_18',
#  'id_23',
#  'id_24',
#  'id_27',
#  'id_28',
#  'id_29',
#  'id_32',
#  'id_34',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38']

# %%
import os

# %%
print(os.getcwd())
# Out:
# /home/watoomi/SafeBank/2-data-stream/c-preprocess-classify

# %%
# we;re going to preserve the column types of all our dataframes from the start

# open tsIdTr.pkl

df2 = pd.read_pickle('/home/watoomi/SafeBank/1-model/for_g_drive/tsIdTr_base.pkl')

# open tsIdTr.pkl

# df2 = pd.read_pickle('/home/1-model/for_g_drive/tsIdTr_base.pkl')tsIdTr_base.pkl')

# %%
column_types = df2.dtypes.to_dict()  # Save original data types

# %%
 = pd.read_pickle('/home/watoomi/SafeBank/2-data-stream/c-preprocess-classify/preprocess_info/preprocess_info.pkl')preprocess_info_to_update

# %%
# Load the existing preprocess_info dictionary from the pickle file
preprocess_info_to_update = pd.read_pickle('/home/watoomi/SafeBank/2-data-stream/c-preprocess-classify/preprocess_info/preprocess_info.pkl')

# Add column_types to preprocess_info_to_update dictionary
preprocess_info_to_update['column_types'] = column_types

# Save the updated dictionary to a pickle file using the pickle module
with open('/home/watoomi/SafeBank/2-data-stream/c-preprocess-classify/preprocess_info/preprocess_info.pkl', 'wb') as file:
    pickle.dump(preprocess_info_to_update, file)

# %%
preprocess_info_updated = pd.read_pickle('/home/watoomi/SafeBank/2-data-stream/c-preprocess-classify/preprocess_info/preprocess_info.pkl')

# %%
preprocess_info_updated['column_types']
# Out:
# {'TransactionID': dtype('int64'),
#  'TransactionDT': dtype('int64'),
#  'TransactionAmt': dtype('float64'),
#  'ProductCD': dtype('O'),
#  'card1': dtype('int64'),
#  'card2': dtype('float64'),
#  'card3': dtype('float64'),
#  'card4': dtype('O'),
#  'card5': dtype('float64'),
#  'card6': dtype('O'),
#  'addr1': dtype('float64'),
#  'addr2': dtype('float64'),
#  'dist1': dtype('float64'),
#  'dist2': dtype('float64'),
#  'P_emaildomain': dtype('O'),
#  'R_emaildomain': dtype('O'),
#  'C1': dtype('float64'),
#  'C2': dtype('float64'),
#  'C3': dtype('float64'),
#  'C4': dtype('float64'),
#  'C5': dtype('float64'),
#  'C6': dtype('float64'),
#  'C7': dtype('float64'),
#  'C8': dtype('float64'),
#  'C9': dtype('float64'),
#  'C10': dtype('float64'),
#  'C11': dtype('float64'),
#  'C12': dtype('float64'),
#  'C13': dtype('float64'),
#  'C14': dtype('float64'),
#  'D1': dtype('float64'),
#  'D2': dtype('float64'),
#  'D3': dtype('float64'),
#  'D4': dtype('float64'),
# ...

# %%
column_types
# Out:
# {'TransactionID': dtype('int64'),
#  'TransactionDT': dtype('int64'),
#  'TransactionAmt': dtype('float64'),
#  'ProductCD': dtype('O'),
#  'card1': dtype('int64'),
#  'card2': dtype('float64'),
#  'card3': dtype('float64'),
#  'card4': dtype('O'),
#  'card5': dtype('float64'),
#  'card6': dtype('O'),
#  'addr1': dtype('float64'),
#  'addr2': dtype('float64'),
#  'dist1': dtype('float64'),
#  'dist2': dtype('float64'),
#  'P_emaildomain': dtype('O'),
#  'R_emaildomain': dtype('O'),
#  'C1': dtype('float64'),
#  'C2': dtype('float64'),
#  'C3': dtype('float64'),
#  'C4': dtype('float64'),
#  'C5': dtype('float64'),
#  'C6': dtype('float64'),
#  'C7': dtype('float64'),
#  'C8': dtype('float64'),
#  'C9': dtype('float64'),
#  'C10': dtype('float64'),
#  'C11': dtype('float64'),
#  'C12': dtype('float64'),
#  'C13': dtype('float64'),
#  'C14': dtype('float64'),
#  'D1': dtype('float64'),
#  'D2': dtype('float64'),
#  'D3': dtype('float64'),
#  'D4': dtype('float64'),
# ...

# %%
preprocess_info_to_update[''] column_types

# %%
df3.keys()
# Out:
# dict_keys(['trIdTr_initial_columns', 'categorical_features', 'numerical_features', 'low_cardinality_features', 'high_cardinality_features', 'label_encoders', 'target_encodings', 'low_correlation_features', 'final_columns', 'train_before_shape', 'train_after_shape', 'train_columns_before', 'train_columns_after', 'train_columns_removed', 'train_columns_added'])

# %%
df3['categorical_features']
# Out:
# ['ProductCD',
#  'card1',
#  'card2',
#  'card3',
#  'card4',
#  'card5',
#  'card6',
#  'addr1',
#  'addr2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'DeviceType',
#  'DeviceInfo',
#  'id_12',
#  'id_13',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_18',
#  'id_19',
#  'id_20',
#  'id_21',
#  'id_22',
#  'id_23',
#  'id_24',
#  'id_25',
#  'id_26',
#  'id_27',
#  'id_28',
#  'id_29',
#  'id_30',
#  'id_31',
#  'id_32',
#  'id_33',
#  'id_34',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38',
#  'TransactionDT_weekday',
#  'TransactionDT_hour']

# %%
df3['high_cardinality_features']
# Out:
# ['card1',
#  'card2',
#  'card3',
#  'card5',
#  'addr1',
#  'addr2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'DeviceInfo',
#  'id_13',
#  'id_14',
#  'id_17',
#  'id_19',
#  'id_20',
#  'id_21',
#  'id_22',
#  'id_25',
#  'id_26',
#  'id_30',
#  'id_31',
#  'id_33']

# %%
column_types
# Out:
# {'TransactionID': dtype('int64'),
#  'TransactionDT': dtype('int64'),
#  'TransactionAmt': dtype('float64'),
#  'ProductCD': dtype('O'),
#  'card1': dtype('int64'),
#  'card2': dtype('float64'),
#  'card3': dtype('float64'),
#  'card4': dtype('O'),
#  'card5': dtype('float64'),
#  'card6': dtype('O'),
#  'addr1': dtype('float64'),
#  'addr2': dtype('float64'),
#  'dist1': dtype('float64'),
#  'dist2': dtype('float64'),
#  'P_emaildomain': dtype('O'),
#  'R_emaildomain': dtype('O'),
#  'C1': dtype('float64'),
#  'C2': dtype('float64'),
#  'C3': dtype('float64'),
#  'C4': dtype('float64'),
#  'C5': dtype('float64'),
#  'C6': dtype('float64'),
#  'C7': dtype('float64'),
#  'C8': dtype('float64'),
#  'C9': dtype('float64'),
#  'C10': dtype('float64'),
#  'C11': dtype('float64'),
#  'C12': dtype('float64'),
#  'C13': dtype('float64'),
#  'C14': dtype('float64'),
#  'D1': dtype('float64'),
#  'D2': dtype('float64'),
#  'D3': dtype('float64'),
#  'D4': dtype('float64'),
# ...
